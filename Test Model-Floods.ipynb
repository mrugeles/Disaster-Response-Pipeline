# %%
import pandas as pd
from sklearn.externals import joblib
from nlp_utils import NLPUtils
import warnings

warnings.filterwarnings('ignore')
pd.set_option('max_colwidth', 200)

columns = ['related', 'request', 'offer',
   'aid_related', 'medical_help', 'medical_products',
   'search_and_rescue', 'security', 'military', 'child_alone', 'water',
   'food', 'shelter', 'clothing', 'money', 'missing_people',
   'refugees', 'death', 'other_aid', 'infrastructure_related',
   'transport', 'buildings', 'electricity', 'tools', 'hospitals',
   'shops', 'aid_centers', 'other_infrastructure', 'weather_related',
   'floods', 'storm', 'fire', 'earthquake', 'cold', 'other_weather',
   'direct_report', 'genre_direct', 'genre_news', 'genre_social']

nlpUtils = NLPUtils()

dataset = pd.read_csv('datasets/floods.csv').sample(20)
dataset.head()
# Out:
#     Unnamed: 0  \
# 6         2591
# 12        2713
# 0         2121
# 19        1724
# 5         1441
#
#                                                                                                                                         text
# 6   7500 displaced by Bundaberg floods: QUEENSLAND Premier Campbell Newman says flood devastation in Bundaberg is mo... http://t.co/zhx1RU8K
# 12  Queensland flood toll rises to six - Sky News Australia: Sky News AustraliaQueensland flood toll rises to sixSky... http://t.co/dCvlBgPK
# 0         New South Wales braces for river peaks as Queensland counts flood cost http://t.co/JRwl7RU3 #climate #australia #extreme #flooding
# 19                                                                               Photos: Flood water rises in Australia http://t.co/633H7Vz2
# 5                                                   New Scientist  - Australia lurches from fire to flood http://t.co/a5pgSLVJ @newscientist

# %%
model = joblib.load('models/classifier.pkl')

# %%
X = [nlpUtils.vectorize_query(text) for text in dataset['text'].values]

# %%
y_pred = model.predict(X[0])
classification_results = dict(zip(columns, y_pred[0]))

# %%
results = []
for idx, sparse_matrix in enumerate(X):
    y_pred = model.predict(sparse_matrix)
    classification_results = dict(zip(columns, y_pred[0]))
    classification_results =  {key:value for (key,value) in classification_results.items() if value == 1}
    #print(f'query: {dataset.iloc[0][1]}')
    results +=  [','.join(list(classification_results.keys()))]
dataset['predictions'] = results

# %%
dataset[['text', 'predictions']]
# Out:
#                                                                                                                                             text  \
# 6       7500 displaced by Bundaberg floods: QUEENSLAND Premier Campbell Newman says flood devastation in Bundaberg is mo... http://t.co/zhx1RU8K
# 12      Queensland flood toll rises to six - Sky News Australia: Sky News AustraliaQueensland flood toll rises to sixSky... http://t.co/dCvlBgPK
# 0             New South Wales braces for river peaks as Queensland counts flood cost http://t.co/JRwl7RU3 #climate #australia #extreme #flooding
# 19                                                                                   Photos: Flood water rises in Australia http://t.co/633H7Vz2
# 5                                                       New Scientist  - Australia lurches from fire to flood http://t.co/a5pgSLVJ @newscientist
# 4                  PD for Tue 29 Jan 2013: Queensland flood advice, CHC wants meaningful plan, Sleep study and much more... http://t.co/Z5XCO6c7
# 1                            @Harry_Styles it's flooding and there's tornadoes in Queensland, my house is about to flood it's really scary :( 12
# 9       Flood relief appeal launched: THE State Government and the Red Cross have launched Queensland Flood Appeal 2013,... http://t.co/CIUR6xLd
# 7                                                                       Standing with @PaulPisasale  as he does a brief about the floods #bigwet
# 14                                                                           Tornado in Mooloolaba? Got out of there just in time this morning!!
# 18                                                                             @walkabout71 you shouldn't be driving. All the roads are flooding
# 15                                         Queensland's flood crisis deepens as death toll rises to three | The Australian: http://t.co/OOVQ2TTw
# 8                                                           Update: 3 die in Australia flood waters since the weekend - @AP http://t.co/31ltGAQk
# 11    The deadly flood crisis is escalating across southern Queensland  and New South Wales, as Brisbane and Bundaberg ...  http://t.co/pIsHLxLt
# 17                                                                      Queensland's flood crisis deepens | The Australian: http://t.co/4H4cNwIE
# 10  RT @rubyblue70: #Scumbag RT @GCobber99 Abbott has warned Labor may seek to raise taxes to pay for flood relief in Queensland\http://t.co ...
# 3                                           Queensland's flood crisis deepens as death toll rises to three - The Australian http://t.co/L6X7Yl6P
# 16      Baby stuffed in bag, hoisted from flood: Australia's powerful storms led to an amazing rescue of two women and a... http://t.co/Dkfrhyrg
# 13      Clean up begins in flood-stricken Queensland - New Zealand Herald: New Zealand HeraldClean up begins in flood-st... http://t.co/HFFd5iS3
# 2                                             RT @sunriseon7: More images from the Queensland flood crisis #sun7 #qldfloods http://t.co/c88celZO
#
#                                                  predictions
# 6                           related,aid_related,genre_social
# 12                                                   related
# 0                                         related,genre_news
# 19                                      related,genre_social
# 5                       related,weather_related,genre_social
# 4                                       related,genre_social
# 1                                         related,genre_news
# 9                                                    related
# 7                                         related,genre_news
# 14                                      related,genre_direct
# 18                 related,weather_related,floods,genre_news
# 15                                      related,genre_social
# 8   related,request,aid_related,weather_related,genre_social
# 11            related,aid_related,weather_related,genre_news
# 17                                      related,genre_social
# 10                                                   related
# 3                           related,aid_related,genre_social
# 16                related,weather_related,storm,genre_social
# 13                                      related,genre_social
# 2                                       related,genre_social
