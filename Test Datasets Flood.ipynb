# %%
import chardet
import pandas as pd

filename = 'datasets/2015_Nepal_earthquake_and_2013_Queensland_floods_datasets/ACL_ICWSM_2018_datasets/queensland/2013_Queensland_Floods_test.tsv'

with open(filename, 'rb') as file:
    print(chardet.detect(file.read()))
# Out:
# {'encoding': 'utf-8', 'confidence': 0.99, 'language': ''}

# %%
import pandas as pd

dataset = pd.read_csv(filename, delimiter='\t')
print(dataset.shape)
dataset.head()
# Out:
# (3011, 3)
#              tweet_id                                               text  \
# 0  296728042179534848  @MarkSDobson I always thought that, big lad ai...
# 1  295429269948100608  @Maree_22 And this going to continue until tom...
# 2  295354447297642496  Room Available in Jacobs Ridge Ormeau $200.00 ...
# 3  295783277355225088  Dotti Size 6 Sailor/ Air Hostess / Japanese Sc...
# 4  296843667321278464  @Purpletiger79 I really enjoyed doing a photo ...
#
#           label
# 0  not_relevant
# 1  not_relevant
# 2  not_relevant
# 3  not_relevant
# 4  not_relevant

# %%
dataset['label'].unique()
# Out:
# array(['not_relevant', 'relevant'], dtype=object)

# %%
dataset.loc[dataset['label'] == 'relevant']
# Out:
#                 tweet_id                                               text  \
# 1386  295783600161423360  Queensland's flood crisis deepens - The Austra...
# 1387  295828335290884096  Premier Campbell Newman has launched Queenslan...
# 1388  295412327640080384  Waiting out the storm  with slipped_diss  @ Ko...
# 1389  296100614469996544  breaking news Photos: Flood water rises in Aus...
# 1390  295681670592471042  .....the rowing club next to out apartment blo...
# ...                  ...                                                ...
# 3006  296348802871349248  Thoughts go out to the flood victims of Queens...
# 3007  296060105147953154  #leimo http://t.co/WHTlPNTd Keith Urban's Bris...
# 3008  296879372051312640  RT @350: No end in sight for Australia flood v...
# 3009  296786110426791936  Queensland Treasurer Tim Nicholls spoke to Ste...
# 3010  295683502895165440  RT @GrillTeam: The Queensland government has s...
#
#          label
# 1386  relevant
# 1387  relevant
# ...

# %%
pd.set_option('max_colwidth', 200)

dataset.loc[dataset['label'] == 'relevant'][['text']]
# Out:
#                                                                                                                                               text
# 1386  Queensland's flood crisis deepens - The Australian - by: Anonymous ... Sydney Morning Herald Queensland's flood cris... http://t.co/foDjHCRy
# 1387     Premier Campbell Newman has launched Queensland Flood Appeal 2013 with $1 million donation to Red Cross. Visit http://t.co/q53GIuR4 to...
# 1388                                                              Waiting out the storm  with slipped_diss  @ Kookaburra Cafe http://t.co/Pwubs60t
# 1389                                                                   breaking news Photos: Flood water rises in Australia:  http://t.co/aEvC8ZDu
# 1390                                                            .....the rowing club next to out apartment block is underwater, warm &amp; wet....
# ...

# %%
heartquake_df = dataset.loc[dataset['label'] == 'relevant'][['text']].sample(20)

heartquake_df.to_csv('datasets/floods.csv')
