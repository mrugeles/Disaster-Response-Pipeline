# %%
import pandas as pd
from sklearn.externals import joblib
from nlp_utils import NLPUtils
import warnings

warnings.filterwarnings('ignore')
pd.set_option('max_colwidth', 200)

columns = ['related', 'request', 'offer',
   'aid_related', 'medical_help', 'medical_products',
   'search_and_rescue', 'security', 'military', 'child_alone', 'water',
   'food', 'shelter', 'clothing', 'money', 'missing_people',
   'refugees', 'death', 'other_aid', 'infrastructure_related',
   'transport', 'buildings', 'electricity', 'tools', 'hospitals',
   'shops', 'aid_centers', 'other_infrastructure', 'weather_related',
   'floods', 'storm', 'fire', 'earthquake', 'cold', 'other_weather',
   'direct_report', 'genre_direct', 'genre_news', 'genre_social']

nlpUtils = NLPUtils()

dataset = pd.read_csv('datasets/heartquake.csv')
dataset.head()
# Out:
#    Unnamed: 0  \
# 0         769
# 1        1194
# 2         894
# 3        1436
# 4        1043
#
#                                                                                                                        text
# 0  #NepalQuake: Relief Efforts Hampered by Flight Delays; 100s Flee Kathmandu http://t.co/C8sXXnJvAn http://t.co/oeVYU2AQDO
# 1                     woke up happy to be alive prayers out to all the victims of the #NepalEarthquake that shit is no joke
# 2                                                                @PIB_India great work guys #proud #Indians #IndiaWithNepal
# 3                                                           @EconomicTimes What the fuck. This is not Nepal. WHAT THE FUCK.
# 4                                 Roughly 5400 Indians evacuated so far: Foreign Secretary #NepalEarthquake#ThankYouPM #BJP

# %%
model = joblib.load('models/classifier.pkl')

# %%
X = [nlpUtils.vectorize_query(text) for text in dataset['text'].values]

# %%
y_pred = model.predict(X[0])
classification_results = dict(zip(columns, y_pred[0]))

# %%
results = []
for idx, sparse_matrix in enumerate(X):
    y_pred = model.predict(sparse_matrix)
    classification_results = dict(zip(columns, y_pred[0]))
    classification_results =  {key:value for (key,value) in classification_results.items() if value == 1}
    #print(f'query: {dataset.iloc[0][1]}')
    results +=  [','.join(list(classification_results.keys()))]
dataset['predictions'] = results

# %%
dataset[['text', 'predictions']]
# Out:
#                                                                                                                                                            text  \
# 0                                      #NepalQuake: Relief Efforts Hampered by Flight Delays; 100s Flee Kathmandu http://t.co/C8sXXnJvAn http://t.co/oeVYU2AQDO
# 1                                                         woke up happy to be alive prayers out to all the victims of the #NepalEarthquake that shit is no joke
# 2                                                                                                    @PIB_India great work guys #proud #Indians #IndiaWithNepal
# 3                                                                                               @EconomicTimes What the fuck. This is not Nepal. WHAT THE FUCK.
# 4                                                                     Roughly 5400 Indians evacuated so far: Foreign Secretary #NepalEarthquake#ThankYouPM #BJP
# 5                      Canadian PM condoles quake calamity in Nepal promises full assistance: Canada's Prime Minister Stephen Harper ... http://t.co/Bh8hKjasih
# 6                               Thank you #Skype for all calls to and from Nepal are free including calls to mobiles and land lines. #Nepal_Earthquake_Response
# 7                                                                                                                #NepalQuake biggest in almost 100 years #Nepal
# 8                RT @AppStore: Here‚Äį√õ¬™s how you can help those affected by the #NepalEarthquake.  Donate now: http://t.co/ilMVRmI3AS http://t.co/lUO5IWDNkI
# 9                     So glad to hear @EllisJStewart is safe and well-please help with the #NepalEarthquake aid appeal by donating here: http://t.co/knOmwOCdoF
# 10                                                                                 For those of you unaware... An earthquake in Nepal just killed 4,000 people.
# 11                          Let us all come together to #PrayForNepal!  You can also  #AidNepal by donating here: http://t.co/12SzRLD182 http://t.co/Mm4LAoTOEC
# 12                                       RT @htTweets: Prime Minister Modi's instructions were to help Nepal in anyway we can: Indian foreign secy S Jaishankar
# 13  RT @UNWomenAust: 3.2 million women &amp; children are affected. Support UN Women‚Äį√õ¬™s relief efforts in #Nepal. https://t.co/73od9Urfs7 http://t.c‚Äį√õ_
# 14                                                                                  RT @TUTAZGAMD: Nepal, pics 1 hour apart... Crazy... https://t.co/0GaTTAAE7c
# 15                                                                                           Powerful earthquake kills hundreds in Nepal http://t.co/mIjeWPXpqQ
# 16            RT @PreetikaRules: May God bless Nepal n save all the souls there who are strugglin for their lives, n may the ones who lost their lives RI‚Äį√õ_
# 17                 #Earthquake death toll in Nepal rises to 876 -Reuters..its really vry sad news.All my condolnce wid dem.May dey all find d strenght 2 ovrcme
# 18       #Uber is donating for Nepal! Click &amp; know more about this offer&gt;&gt;http://t.co/5CdCWPtopD #earthquake http://t.co/OMjlMAs8qP -TTY:couponrajČŘ_
# 19                                                                                              Doctors in Nepal appealing for more help http://t.co/NMcW1gaYMu
#
#                                                              predictions
# 0                                                   related,genre_social
# 1                                       related,aid_related,genre_social
# 2
# 3                                      related,genre_direct,genre_social
# 4                                                 aid_related,genre_news
# 5                        related,weather_related,earthquake,genre_social
# 6   related,other_aid,weather_related,earthquake,genre_direct,genre_news
# 7                                        related,genre_direct,genre_news
# 8                                                   related,genre_social
# 9                              related,request,genre_direct,genre_social
# 10                  related,aid_related,death,weather_related,earthquake
# 11                                    related,direct_report,genre_social
# 12                                                               related
# 13                       related,weather_related,genre_news,genre_social
# 14                                            related,storm,genre_social
# 15           related,aid_related,weather_related,earthquake,genre_social
# 16                                                  related,genre_direct
# 17                  related,aid_related,death,weather_related,earthquake
# 18                       related,weather_related,earthquake,genre_social
# 19                                  related,weather_related,genre_social
